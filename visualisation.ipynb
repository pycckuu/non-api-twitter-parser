# %%
from tweets_parser import *

# %%
scrape_page('https://twitter.com/search?f=news&vertical=news&q=water%20since%3A2015-09-01%20until%3A2015-10-18&src=typd&lang=en')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-242b34d04db6> in <module>()
# ----> 1 scrape_page('https://twitter.com/search?f=news&vertical=news&q=water%20since%3A2015-09-01%20until%3A2015-10-18&src=typd&lang=en')
#
# /Users/MarkelovIgor/Documents/git/non-api-twitter-parser/tweets_parser.py in scrape_page(page_url)
#      25     for i in range(1,100000):
#      26       driver.execute_script("window.scrollTo(0, document.body.scrollHeight);") #scroll down
# ---> 27       time.sleep(0.5)
#      28
#      29
#
# KeyboardInterrupt:

# %%
import pandas as pd
# %matplotlib inline 
import matplotlib.pylab as pylab
pylab.rcParams['figure.figsize'] = 16, 8  # that's default image size for this interactive session

region = {}
region['UK'] = daily_count_words(['uk'], prsd_tweets)
region['US'] = daily_count_words(['us'], prsd_tweets)
region['California'] = daily_count_words(['california'], prsd_tweets)
region['India'] = daily_count_words(['india'], prsd_tweets)
region['World'] = daily_count_words(['world','global'], prsd_tweets)

cond = {}
cond['Droughts'] = daily_count_words(['drought'], prsd_tweets) 
cond['Floods'] = daily_count_words(['flood'], prsd_tweets)

science = {}
science['Mars'] = daily_count_words(['mars'], prsd_tweets)
science['Study'] = daily_count_words(['study'], prsd_tweets)
science['Climate'] = daily_count_words(['climate'], prsd_tweets)
science['Ice'] = daily_count_words(['ice'], prsd_tweets)
science['Plastic'] = daily_count_words(['plastic'], prsd_tweets)
science['Contamination'] = daily_count_words(['toxic','contaminat'], prsd_tweets) 

health = {}
health['Drink'] = daily_count_words(['drink'], prsd_tweets) 
health['Fish'] = daily_count_words(['fish'], prsd_tweets) 
health['Health'] = daily_count_words(['health'], prsd_tweets) 
health['Clean'] = daily_count_words(['clean'], prsd_tweets) 
health['Monitoring'] = daily_count_words(['monitor','assesment'], prsd_tweets) 
health['Water Poverty'] = daily_count_words(['poverty'], prsd_tweets) 

work = {}

work['Farmers'] = daily_count_words(['farmer'], prsd_tweets) 
work['Industry'] = daily_count_words(['industr'], prsd_tweets) 


news = {}
news['CTV'] = daily_count_words(['ctv'], prsd_tweets) 
news['CBC'] = daily_count_words(['cbc'], prsd_tweets) 
news['BBC'] = daily_count_words(['bbc'], prsd_tweets) 
news['CNN'] = daily_count_words(['cnn'], prsd_tweets) 
news['NBC'] = daily_count_words(['nbc'], prsd_tweets) 
news['FOXTV'] = daily_count_words(['foxtv'], prsd_tweets) 

elec = {}
elec['NDP'] = daily_count_words(['ndp'], prsd_tweets)
elec['Conservative'] = daily_count_words(['pc'], prsd_tweets)
elec['Liberal'] = daily_count_words(['liberal'], prsd_tweets)

typ={}
typ['Sea'] = daily_count_words(['sea'], prsd_tweets) 
typ['Ocean'] = daily_count_words(['ocean'], prsd_tweets) 
typ['Lake'] = daily_count_words(['lake'], prsd_tweets) 
typ['River'] = daily_count_words(['river'], prsd_tweets) 
typ['Wetlands'] = daily_count_words(['wetlands','marsh','bog','swamp'], prsd_tweets) 

cities = {}
cities['Baltimore city, US'] = daily_count_words(['baltimore'], prsd_tweets)
cities['Bay city , US'] = daily_count_words(['bay city'], prsd_tweets)
cities['Desmoine city, US'] = daily_count_words(['desmoine'], prsd_tweets)
cities['Lancaster city, US'] = daily_count_words(['lancaster'], prsd_tweets)
cities['Portland city, US'] = daily_count_words(['portland'], prsd_tweets)
cities['Tulsa city, US'] = daily_count_words(['tulsa'], prsd_tweets)
cities['Wisconsin city, US'] = daily_count_words(['wisconsin'], prsd_tweets)


cities_w = {}
cities_w['Cork city, Ireland'] = daily_count_words(['cork'], prsd_tweets)
cities_w['Limerick city, Ireland'] = daily_count_words(['limerick'], prsd_tweets)
cities_w['Toronto city, Canada'] = daily_count_words(['toronto'], prsd_tweets)
cities_w['Dhaka city, Bangladesh'] = daily_count_words(['dhaka'], prsd_tweets)
cities_w['Manchester city, England'] = daily_count_words(['manchester'], prsd_tweets)
cities_w['Mumbai city, India'] = daily_count_words(['mumbai'], prsd_tweets)
cities_w['Tulcea city, Romania'] = daily_count_words(['tulcea'], prsd_tweets)

us_pre = {}
us_pre['Obama'] = daily_count_words(['obama'], prsd_tweets)
us_pre['Trump'] = daily_count_words(['trump'], prsd_tweets)


df1 = pd.DataFrame(region )
df2 = pd.DataFrame(cond )
df3 = pd.DataFrame(science )
df4 = pd.DataFrame(health )
df5 = pd.DataFrame(work )
df6 = pd.DataFrame(news )
df7 = pd.DataFrame(elec)
df8 = pd.DataFrame(typ)
df9 = pd.DataFrame(cities)
df10 = pd.DataFrame(cities_w)
df11 = pd.DataFrame(us_pre)


df1[1:].plot(kind='area')
df2[1:].plot(kind='area')
df3[1:].plot(kind='area')
df4[1:].plot(kind='area')
df5[1:].plot(kind='area')
df6[1:].plot(kind='area')
df7[1:].plot(kind='area')
df8[1:].plot(kind='area')
df9[1:].plot(kind='area')
df10[1:].plot(kind='area')
df11[1:].plot(kind='area')

# %%
df1[-30:]
# Out:
#             california  india  uk   us  world
# 2015-12-01         100     13  15  294     67
# 2015-12-02          37     60  11  301     73
# 2015-12-03          31     30  12  360     90
# 2015-12-04          33     20  13  261     39
# 2015-12-05          17     10  10  163     27
# 2015-12-06          14      6   9  189     34
# 2015-12-07          40     12  31  373     45
# 2015-12-08          55     12  28  369     42
# 2015-12-09          29     12  15  291     46
# 2015-12-10          24     16  14  316     41
# 2015-12-11          22     21  12  223     40
# 2015-12-12           8      6   6  193     29
# 2015-12-13           5      1   1   65     11
# 2015-12-14          19     30  12  330     22
# 2015-12-15          24     15  17  287     34
# 2015-12-16          12     20  55  221     29
# 2015-12-17           9      4  12  155     31
# 2015-12-18          15      4  10  167     27
# 2015-12-19           1      5   5   95     28
# ...
